# %% [markdown]
# # Ex2 - Getting and Knowing your Data

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv",sep="\t")
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?

# %%
# Solution 1
x = len(chipo)

print("Number of observations:", x)
# Out:
# Number of observations: 4622

# %%
# Solution 2

x = chipo.shape[0]

print("Number of observations:", x)
# Out:
# Number of observations: 4622

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
x = chipo.shape[1]

print("Number of columns:", x)
# Out:
# Number of columns: 5

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
# ### Step 8. How is the dataset indexed?

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %% [markdown]
# ### Step 9. Which was the most-ordered item?

# %%
chipo['item_name'].value_counts().sort_values(ascending=False).head(1)
# Out:
# Chicken Bowl    726
# Name: item_name, dtype: int64

# %% [markdown]
# ### Step 10. For the most-ordered item, how many items were ordered?

# %%
max_ordered_quantity = chipo.groupby('item_name')['quantity'].sum().max()
max_ordered_quantity
# Out:
# 761

# %% [markdown]
# ### Step 11. What was the most ordered item in the choice_description column?

# %%
most_ordered_item = chipo.groupby('choice_description')['quantity'].sum().idxmax()
most_ordered_item
# Out:
# '[Diet Coke]'

# %% [markdown]
# ### Step 12. How many items were orderd in total?

# %%
items_were_orderd = chipo['quantity'].sum()
items_were_orderd
# Out:
# 4972

# %% [markdown]
# ### Step 13. Turn the item price into a float

# %%
chipo['item_price'] = chipo['item_price'].str.replace('$', '').astype(float)

# Verify the data type conversion
print(chipo['item_price'].dtype)
# Out:
# float64
# C:\Users\Ahmed\AppData\Local\Temp\ipykernel_21084\2832234341.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   chipo['item_price'] = chipo['item_price'].str.replace('$', '').astype(float)

# %% [markdown]
# #### Step 13.a. Check the item price type

# %%
chipo['item_price'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# #### Step 13.b. Create a lambda function and change the type of item price

# %%
#convert_to_float = lambda x: float(x.replace('$', ''))

#chipo['item_price'] = chipo['item_price'].apply(convert_to_float)

# %% [markdown]
# #### Step 13.c. Check the item price type

# %%
chipo['item_price'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### Step 14. How much was the revenue for the period in the dataset?

# %%
x = chipo['item_price'] * chipo['quantity']
print(f"the revenue : {x.sum()}")
# Out:
# the revenue : 39237.02

# %% [markdown]
# ### Step 15. How many orders were made in the period?

# %%
x = chipo['order_id'].nunique()

print(f"Number of orders : {x}")
# Out:
# Number of orders : 1834

# %% [markdown]
# ### Step 16. What is the average revenue amount per order?

# %%
# Solution 1
order_revenue = chipo.groupby('order_id')['item_price'].sum().mean()

print("Average Revenue per Order: $", order_revenue)
# Out:
# Average Revenue per Order: $ 18.811428571428568

# %%
# Solution 2

#total_revenue = chipo['revenue'].sum()
#total_orders = chipo['order_id'].nunique()

#average_revenue_per_order = total_revenue / total_orders
#print(f"Average revenue amount per order: {average_revenue_per_order}$")

# %% [markdown]
# ### Step 17. How many different items are sold?

# %%
unique_items = chipo['item_name'].nunique()
unique_items
# Out:
# 50
